# %%
print("Hello")
# Out:
# Hello

# %%
from trading_ig import IGService

# %%
from trading_ig.rest import IGService
from trading_ig.config import config

# %%
ig_service = IGService(config.username, config.password, config.api_key)

# %%
ig = ig_service.create_session()
# Out:
# ---------------------------------------------------------------------------
# InvalidHeader                             Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 ig = ig_service.create_session()
#
# File d:\Projects\IG-Broker\trading-ig\trading_ig\rest.py:2071, in IGService.create_session(self, session, encryption, version)
#    2069 endpoint = "/session"
#    2070 action = "create"
# -> 2071 response = self._req(action, endpoint, params, session, version, check=False)
#    2072 self._manage_headers(response)
#    2073 data = self.parse_response(response.text)
#
# File d:\Projects\IG-Broker\trading-ig\trading_ig\rest.py:379, in IGService._req(self, action, endpoint, params, session, version, check)
#     375     result = self._retryer.__call__(
#     376         self._request, action, endpoint, params, session, version, check
#     377     )
#     378 else:
# --> 379     result = self._request(action, endpoint, params, session, version, check)
#     381 return result
#
# File d:\Projects\IG-Broker\trading-ig\trading_ig\rest.py:388, in IGService._request(self, action, endpoint, params, session, version, check)
#     386 if check:
#     387     self._check_session()
# --> 388 response = self.crud_session.req(action, endpoint, params, session, version)
#     390 if response.status_code >= 500:
#     391     raise (
#     392         IGException(
#     393             f"Server problem: status code: {response.status_code}, "
#     394             f"reason: {response.reason}"
#     395         )
#     396     )
#
# File d:\Projects\IG-Broker\trading-ig\trading_ig\rest.py:163, in IGSessionCRUD.req(self, action, endpoint, params, session, version)
#     156 """Send a request (CREATE READ UPDATE or DELETE)"""
#     157 d_actions = {
#     158     "create": self.create,
#     159     "read": self.read,
#     160     "update": self.update,
#     161     "delete": self.delete,
#     162 }
# --> 163 return d_actions[action](endpoint, params, session, version)
#
# File d:\Projects\IG-Broker\trading-ig\trading_ig\rest.py:108, in IGSessionCRUD.create(self, endpoint, params, session, version)
#     106 session = self._get_session(session)
#     107 session.headers.update({"VERSION": version})
# --> 108 response = session.post(url, data=json.dumps(params))
#     109 logger.info(f"POST '{endpoint}', resp {response.status_code}")
#     110 if response.status_code in [401, 403]:
#
# File d:\Projects\IG-Broker\Lib\site-packages\requests\sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)    634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File d:\Projects\IG-Broker\Lib\site-packages\requests\sessions.py:575, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     562 # Create the Request.
#     563 req = Request(
#     564     method=method.upper(),
#     565     url=url,
#    (...)    573     hooks=hooks,
#     574 )
# --> 575 prep = self.prepare_request(req)
#     577 proxies = proxies or {}
#     579 settings = self.merge_environment_settings(
#     580     prep.url, proxies, stream, verify, cert
#     581 )
#
# File d:\Projects\IG-Broker\Lib\site-packages\requests\sessions.py:484, in Session.prepare_request(self, request)
#     481     auth = get_netrc_auth(request.url)
#     483 p = PreparedRequest()
# --> 484 p.prepare(
#     485     method=request.method.upper(),
#     486     url=request.url,
#     487     files=request.files,
#     488     data=request.data,
#     489     json=request.json,
#     490     headers=merge_setting(
#     491         request.headers, self.headers, dict_class=CaseInsensitiveDict
#     492     ),
#     493     params=merge_setting(request.params, self.params),
#     494     auth=merge_setting(auth, self.auth),
#     495     cookies=merged_cookies,
#     496     hooks=merge_hooks(request.hooks, self.hooks),
#     497 )
#     498 return p
#
# File d:\Projects\IG-Broker\Lib\site-packages\requests\models.py:368, in PreparedRequest.prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     366 self.prepare_method(method)
#     367 self.prepare_url(url, params)
# --> 368 self.prepare_headers(headers)
#     369 self.prepare_cookies(cookies)
#     370 self.prepare_body(data, files, json)
#
# File d:\Projects\IG-Broker\Lib\site-packages\requests\models.py:490, in PreparedRequest.prepare_headers(self, headers)
#     487 if headers:
#     488     for header in headers.items():
#     489         # Raise exception on invalid header value.
# --> 490         check_header_validity(header)
#     491         name, value = header
#     492         self.headers[to_native_string(name)] = value
#
# File d:\Projects\IG-Broker\Lib\site-packages\requests\utils.py:1032, in check_header_validity(header)
#    1030 name, value = header
#    1031 _validate_header_part(header, name, 0)
# -> 1032 _validate_header_part(header, value, 1)
#
# File d:\Projects\IG-Broker\Lib\site-packages\requests\utils.py:1041, in _validate_header_part(header, header_part, header_validator_index)
#    1039     validator = _HEADER_VALIDATORS_BYTE[header_validator_index]
#    1040 else:
# -> 1041     raise InvalidHeader(
#    1042         f"Header part ({header_part!r}) from {header} "
#    1043         f"must be of type str or bytes, not {type(header_part)}"
#    1044     )
#    1046 if not validator.match(header_part):
#    1047     header_kind = "name" if header_validator_index == 0 else "value"
#
# InvalidHeader: Header part (('fa51b09392954a22298b67d2dfd765cfeac8fe26',)) from ('X-IG-API-KEY', ('fa51b09392954a22298b67d2dfd765cfeac8fe26',)) must be of type str or bytes, not <class 'tuple'>

# %%
ig
# Out:
# {'accountType': 'SPREADBET',
#  'accountInfo': {'balance': 9897.82,
#   'deposit': 40.68,
#   'profitLoss': -1.66,
#   'available': 9855.48},
#  'currencyIsoCode': 'GBP',
#  'currencySymbol': '£',
#  'currentAccountId': 'Z63VU2',
#  'lightstreamerEndpoint': 'https://demo-apd.marketdatasystems.com',
#  'accounts': [{'accountId': 'Z63VU1',
#    'accountName': 'CFD',
#    'preferred': False,
#    'accountType': 'CFD'},
#   {'accountId': 'Z63VU2',
#    'accountName': 'Spread bet',
#    'preferred': True,
#    'accountType': 'SPREADBET'}],
#  'clientId': '104491163',
#  'timezoneOffset': 0,
#  'hasActiveDemoAccounts': True,
#  'hasActiveLiveAccounts': True,
#  'trailingStopsEnabled': False,
#  'reroutingEnvironment': None,
#  'dealingEnabled': True}

# %%
accounts = ig_service.fetch_accounts()

# %%
accounts
# Out:
#   accountId accountName accountAlias   status accountType  preferred currency  \
# 0    Z63VU1         CFD         None  ENABLED         CFD      False      GBP
# 1    Z63VU2  Spread bet         None  ENABLED   SPREADBET       True      GBP
#
#    canTransferFrom  canTransferTo  available   balance  deposit  profitLoss
# 0             True           True   10491.54  10491.54     0.00        0.00
# 1             True           True    9855.45   9897.82    40.68       -1.69

# %%
accounts.accountId
# Out:
# 0    Z63VU1
# 1    Z63VU2
# Name: accountId, dtype: object

# %%
accounts.balance[0]
# Out:
# np.float64(10491.54)

# %%
account_info =  ig_service.fetch_accounts()

# %%
account_info
# Out:
#   accountId accountName accountAlias   status accountType  preferred currency  \
# 0    Z63VU1         CFD         None  ENABLED         CFD      False      GBP
# 1    Z63VU2  Spread bet         None  ENABLED   SPREADBET       True      GBP
#
#    canTransferFrom  canTransferTo  available   balance  deposit  profitLoss
# 0             True           True   10491.54  10491.54     0.00        0.00
# 1             True           True    9858.11   9897.82    40.82        1.11

# %%
balance =account_info.balance[0]

# %%
balance
# Out:
# np.float64(10491.54)

# %%
 market_info = ig_service.fetch_market_by_epic("CS.D.EURUSD.MINI.IP")

# %%
market_info
# Out:
# Munch({'instrument': Munch({'epic': 'CS.D.EURUSD.MINI.IP', 'expiry': '-', 'name': 'EUR/USD Mini', 'forceOpenAllowed': True, 'stopsLimitsAllowed': True, 'lotSize': 1.0, 'unit': 'AMOUNT', 'type': 'CURRENCIES', 'controlledRiskAllowed': True, 'streamingPricesAvailable': False, 'marketId': 'EURUSD', 'currencies': [Munch({'code': 'USD', 'symbol': '$', 'baseExchangeRate': 1.315624, 'exchangeRate': 0.66, 'isDefault': False})], 'sprintMarketsMinimumExpiryTime': None, 'sprintMarketsMaximumExpiryTime': None, 'marginDepositBands': [Munch({'min': 0, 'max': 578, 'margin': 3.33, 'currency': 'USD'}), Munch({'min': 578, 'max': 2890, 'margin': 3.33, 'currency': 'USD'}), Munch({'min': 2890, 'max': 4624, 'margin': 3.33, 'currency': 'USD'}), Munch({'min': 4624, 'max': None, 'margin': 15, 'currency': 'USD'})], 'marginFactor': 3.33, 'marginFactorUnit': 'PERCENTAGE', 'slippageFactor': Munch({'unit': 'pct', 'value': 50.0}), 'limitedRiskPremium': Munch({'value': 1.2, 'unit': 'POINTS'}), 'openingHours': None, 'expiryDetails': None, 'rolloverDetails': None, 'newsCode': 'EUR=', 'chartCode': 'EURUSD', 'country': None, 'valueOfOnePip': None, 'onePipMeans': None, 'contractSize': None, 'specialInfo': ['DEFAULT KNOCK OUT LEVEL DISTANCE', 'MIN KNOCK OUT LEVEL DISTANCE', 'MAX KNOCK OUT LEVEL DISTANCE']}), 'dealingRules': Munch({'minStepDistance': Munch({'unit': 'POINTS', 'value': 5.0}), 'minDealSize': Munch({'unit': 'POINTS', 'value': 0.04}), 'minControlledRiskStopDistance': Munch({'unit': 'POINTS', 'value': 5.0}), 'minNormalStopOrLimitDistance': Munch({'unit': 'POINTS', 'value': 2.0}), 'maxStopOrLimitDistance': Munch({'unit': 'PERCENTAGE', 'value': 75.0}), 'controlledRiskSpacing': Munch({'unit': 'POINTS', 'value': 20.0}), 'marketOrderPreference': 'AVAILABLE_DEFAULT_OFF', 'trailingStopsPreference': 'AVAILABLE'}), 'snapshot': Munch({'marketStatus': 'TRADEABLE', 'netChange': -0.2, 'percentageChange': 0, 'updateTime': '22:00:11', 'delayTime': 0, 'bid': 13050.8, 'offer': 13052.8, 'high': 13053.3, 'low': 13050.4, 'binaryOdds': None, 'decimalPlacesFactor': 1, 'scalingFactor': 1, 'controlledRiskExtraSpread': 2.4})})

# %%
market_info

# %%
epic = "CCS.D.USCGC.TODAY.IP"

market_info = ig_service.fetch_market_by_epic(epic)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 epic = "CCS.D.USCGC.TODAY.IP"
# ----> 3 market_info = ig_service.fetch_market_by_epic(epic)
#
# NameError: name 'ig_service' is not defined

# %%
test = market_info['snapshot']['bid']

# %%
test
# Out:
# 13050.8
